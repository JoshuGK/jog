# %%
import pandas as pd
a = [4,5,6,7]
table=pd.Series(a,index=["day","jog","day2","day3"])
print(table)
# Out:
# day     4
# jog     5
# day2    6
# day3    7
# dtype: int64

# %%
a={"new":[4,5,6,7],
   "month":["jan","feb","march","april"]
   }
tab=pd.DataFrame(a,index=["day","jog","day2","day3"])
print(tab)
# Out:
#       new  month
# day     4    jan
# jog     5    feb
# day2    6  march
# day3    7  april

# %%
import pandas as pd
import matplotlib.pyplot as plt

#with open("data.csv")as data:
   # cotents=data.read()
#print(cotents)

cotents=pd.read_csv("data.csv")
#print(cotents)
#plotting with pandas
cotents.plot(kind='scatter',x='Duration',y='Pulse')
plt.show()
